# %% [markdown]
# Question 1: Explain the role of activation functions in neural networks. Compare and contrast linear and nonlinear activation functions. Why are nonlinear activation functions preferred in hidden layers?

# %%
#Answer

# %% [markdown]
# Role of Activation Functions
# Activation functions introduce non-linearity in neural networks, enabling them to learn complex patterns from data. They help in:
#
# Transforming the input signal to an output signal.
# Controlling which neurons activate, adding non-linearity to model complex relationships.
# Ensuring that neural networks can approximate any function.
# Linear vs. Nonlinear Activation Functions
# Feature	Linear Activation	Nonlinear Activation
# Equation
# 𝑓
# (
# 𝑥
# )
# =
# 𝑎
# 𝑥
# +
# 𝑏
# f(x)=ax+b
# 𝑓
# (
# 𝑥
# )
# =
# f(x)= (e.g., Sigmoid, ReLU, Tanh)
# Non-linearity	No	Yes
# Learning Capacity	Limited to linear transformations	Can model complex, nonlinear relationships
# Stacking in Hidden Layers	Ineffective	Essential for deep learning
# Why Nonlinear Activation Functions in Hidden Layers?
# Without non-linearity, multiple layers collapse into a single linear transformation.
# Nonlinear functions allow neural networks to capture intricate patterns.
# They help gradient-based optimization techniques converge efficiently.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
linear = x
nonlinear = np.tanh(x)

plt.plot(x, linear, label='Linear')
plt.plot(x, nonlinear, label='Nonlinear (Tanh)')
plt.legend()
plt.show()

# %% [markdown]
# Question 2: Describe the Sigmoid activation function. What are its characteristics, and in what type of layers is it commonly used?

# %%
#Answer

# %% [markdown]
# Sigmoid Activation Function
# The Sigmoid function is given by:
#
# 𝜎
# (
# 𝑥
# )
# =
# 1
# 1
# +
# 𝑒
# −
# 𝑥
# σ(x)=
# 1+e
# −x
#
# 1
# ​
#
# Characteristics:
# Range: (0,1) – outputs probabilities.
# Differentiable – supports gradient-based optimization.
# S-shaped curve – squashes input into a small range.
# Common Usage:
# Output layers in binary classification problems.
# Not often used in hidden layers due to vanishing gradient problem.

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.linspace(-10, 10, 100)
y = sigmoid(x)

plt.plot(x, y)
plt.title("Sigmoid Activation Function")
plt.show()

# %% [markdown]
# Question 3: Explain the Rectified Linear Unit (ReLU) activation function. Discuss its advantages and potential challenges.

# %%
#Answer

# %% [markdown]
# ReLU Activation Function
# Defined as:
#
# 𝑓
# (
# 𝑥
# )
# =
# max
# ⁡
# (
# 0
# ,
# 𝑥
# )
# f(x)=max(0,x)
# Advantages:
# Solves vanishing gradient problem of Sigmoid.
# Faster training due to non-saturating gradients.
# Introduces sparsity (some neurons output 0).
# Challenges:
# Dying ReLU problem: Neurons can become inactive when they always output zero.
# Does not handle negative values well.

# %%
def relu(x):
    return np.maximum(0, x)

x = np.linspace(-10, 10, 100)
y = relu(x)

plt.plot(x, y)
plt.title("ReLU Activation Function")
plt.show()

# %% [markdown]
# Question 4: What is the purpose of the Tanh activation function? How does it differ from the Sigmoid activation function?

# %%
#Answer

# %% [markdown]
# Tanh Activation Function
# tanh
# ⁡
# (
# 𝑥
# )
# =
# 𝑒
# 𝑥
# −
# 𝑒
# −
# 𝑥
# 𝑒
# 𝑥
# +
# 𝑒
# −
# 𝑥
# tanh(x)=
# e
# x
#  +e
# −x
#
# e
# x
#  −e
# −x
#
# ​
#
# Differences from Sigmoid:
# Feature	Sigmoid	Tanh
# Range	(0,1)	(-1,1)
# Centered at	0.5	0
# Gradient Vanishing Risk	Yes	Lower than Sigmoid
# Better For	Probabilities	Zero-centered transformations
# Purpose of Tanh:
# Used in hidden layers to balance gradients.
# Better than Sigmoid for avoiding biased activations.

# %%
def tanh(x):
    return np.tanh(x)

x = np.linspace(-10, 10, 100)
y = tanh(x)

plt.plot(x, y)
plt.title("Tanh Activation Function")
plt.show()

# %% [markdown]
# Question 5: Discuss the significance of activation functions in the hidden layers of a neural network.

# %%
#Answer

# %% [markdown]
# They introduce non-linearity, allowing networks to learn complex representations.
# Help in gradient propagation during backpropagation.
# Ensure efficient training convergence.
# Reduce computation costs (e.g., ReLU is computationally cheap).

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

model = Sequential([
    Dense(10, activation='relu', input_shape=(5,)),
    Dense(10, activation='tanh'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# ...

# %% [markdown]
# Question 6: Explain the choice of activation functions for different types of problems (e.g., classification, regression) in the output layer.

# %%
#Answer

# %% [markdown]
# Problem Type	Common Activation Function	Explanation
# Binary Classification	Sigmoid	Outputs probability (0 to 1)
# Multiclass Classification	Softmax	Converts logits into probabilities
# Regression	Linear	Outputs continuous values
# Hidden Layers	ReLU, Tanh	Non-linearity for feature extraction

# %%
classification_model = Sequential([
    Dense(10, activation='relu', input_shape=(5,)),
    Dense(1, activation='sigmoid') # For binary classification
])

regression_model = Sequential([
    Dense(10, activation='relu', input_shape=(5,)),
    Dense(1, activation='linear') # For regression
])

# %% [markdown]
# Question 7: Experiment with different activation functions (e.g., ReLU, Sigmoid, Tanh) in a simple neural network architecture. Compare their effects on convergence and performance.

# %%
#Answer

# %% [markdown]
# Python Example:
# We will train a simple neural network using different activation functions and compare their performances.

# %%
import tensorflow as tf

def create_model(activation):
    model = Sequential([
        Dense(10, activation=activation, input_shape=(2,)),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

activations = ['relu', 'sigmoid', 'tanh']
for act in activations:
    model = create_model(act)
    print(f"Model with {act} activation function:")
    model.summary()
# Out:
# Model with relu activation function:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)
# Model with sigmoid activation function:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ...
